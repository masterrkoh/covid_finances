# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df1=pd.read_csv('xle_us_d.csv')
df2=pd.read_csv('xlf_us_d.csv')
df3=pd.read_csv('xlv_us_d.csv')
df4=pd.read_csv('xly_us_d.csv')
df5=pd.read_csv('xlk_us_d.csv')

# %%
df1.head()
# Out:
#          Date     Open     High      Low    Close    Volume
# 0  2019-01-02  20.5121  21.3944  20.4073  21.2533  68491960
# 1  2019-01-03  21.3152  21.3915  20.8027  21.0434  49593065
# 2  2019-01-04  21.4065  21.8245  21.2832  21.7587  58748459
# 3  2019-01-07  21.9215  22.2433  21.6318  22.0826  49683467
# 4  2019-01-08  22.3913  22.4430  22.1332  22.2537  51431771

# %%
df2.head()
# Out:
#          Date     Open     High      Low    Close        Volume
# 0  2019-01-02  21.7213  22.2765  21.6581  22.2310  6.801001e+07
# 1  2019-01-03  22.0648  22.1212  21.6759  21.7313  7.101915e+07
# 2  2019-01-04  22.1024  22.4982  22.0460  22.4526  6.983964e+07
# 3  2019-01-07  22.4071  22.6823  22.2676  22.4794  5.204291e+07
# 4  2019-01-08  22.6823  22.7149  22.2389  22.4982  9.736599e+07

# %%
df3.head()
# Out:
#          Date     Open     High      Low    Close        Volume
# 0  2019-01-02  80.0669  80.6779  79.2130  80.0858  1.508547e+07
# 1  2019-01-03  80.1989  80.3675  78.2529  78.4582  1.879632e+07
# 2  2019-01-04  79.3806  81.2403  79.3429  80.7989  1.730108e+07
# 3  2019-01-07  80.8277  81.8711  80.5836  81.1113  1.317829e+07
# 4  2019-01-08  81.7600  82.0139  80.8376  81.7401  1.422486e+07

# %%
df4.head()
# Out:
#          Date     Open     High      Low    Close    Volume
# 0  2019-01-02  45.6069  47.0089  45.3568  46.7484  14597822
# 1  2019-01-03  46.3929  46.5057  45.6573  45.7367  13542469
# 2  2019-01-04  46.3545  47.6023  46.2625  47.2488  15512035
# 3  2019-01-07  47.4764  48.6258  47.4526  48.3111  13365239
# 4  2019-01-08  48.8145  49.1141  48.1660  48.8483  20039835

# %%
df5.head()
# Out:
#          Date     Open     High      Low    Close    Volume
# 0  2019-01-02  28.4565  29.2443  28.4191  29.0708  32946390
# 1  2019-01-03  28.3297  28.3486  27.5666  27.6031  53222092
# 2  2019-01-04  28.1088  28.9489  28.0215  28.8263  44307024
# 3  2019-01-07  28.8263  29.2816  28.7616  29.0849  25406895
# 4  2019-01-08  29.3660  29.4685  28.9811  29.3281  27740138

# %%
plt.plot(df1['Date'], df1['Close'], label='Energy')
plt.plot(df2['Date'], df2['Close'], label='Finance')
plt.plot(df3['Date'], df3['Close'], label='Health')
plt.plot(df4['Date'], df4['Close'], label='Technology')
plt.plot(df5['Date'], df5['Close'], label='Consumer discretionary')
plt.title('Recovery time of stocks')
plt.xlabel('Date')
plt.ylabel('Price(USD)')
plt.legend()
